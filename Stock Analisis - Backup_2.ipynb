# %%
import ta
import os
import math
import tqdm
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import cufflinks as cf
import tensorflow as tf
import plotly.express as px
import chart_studio.plotly as py

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %matplotlib inline

init_notebook_mode(connected=True)
cf.go_offline()

gpus = tf.config.list_physical_devices('GPU')
if gpus:
  # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5120)])
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)

MODELS_DIR = "Models"
DATA_DIR = "Data"


def next_free_model_name(base_name: str) -> str:
    model_files = [name for name in os.listdir(MODELS_DIR) if name.split(".")[-1].lower() == "h5"]
    similar_models_numbers = [int(name.split("_")[-1].split(".")[0]) for name in model_files if name.find(base_name) >= 0]
    
    if len(similar_models_numbers) > 0:
        max_value = str(max(similar_models_numbers)+1).zfill(3)
        new_name = base_name + "_" + max_value
    else:
        new_name = base_name + "_000"
    return new_name


def infinite_iterator(data: list or tuple or str) -> list or tuple or char or str:
    while True:
        for item in data:
            yield item
            

def generate_input_sequences(data: pd.DataFrame, input_length=30, output_length=1) -> np.ndarray:
    price_array = data.to_numpy()
    input_sequences = np.zeros((price_array.shape[0] - input_length - output_length,
                                input_length, price_array.shape[1]), dtype=float)
    for index in range(input_sequences.shape[0]):
        input_sequences[index] = price_array[index:index+input_length, :]
    return input_sequences


def generate_output_sequences(data: pd.DataFrame, outputs: list, input_length=30, output_length=1) -> np.ndarray:
    selected_dataframe = data[outputs]
    price_array = selected_dataframe.to_numpy()
    if output_length == 1:
        output_sequences = np.zeros((price_array.shape[0] - input_length - output_length,
                                     price_array.shape[1]), dtype=float)
        for index in range(output_sequences.shape[0]):
            output_sequences[index] = price_array[index+input_length : index+input_length+output_length, :] 
    else:
        output_sequences = np.zeros((price_array.shape[0] - input_length - output_length,
                                     output_length, price_array.shape[1]), dtype=float)
        for index in range(output_sequences.shape[0]):
            output_sequences[index] = price_array[index+input_length : index+input_length+output_length, :]
    return output_sequences


def
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# # New York Stock Exchange Data
# Dataset seleceted for project [New York Stock Exchange Data] contains large amount of data separated into 4 files.
# ____
# * **fundamentals.csv**
# metrics extracted from annual SEC 10K fillings (2012-2016), should be enough to derive most of popular fundamental indicators.
# ----
# * **securities.csv**
# general description of each company with division on sectors
# ----
# * **prices-split-adjusted.csv**
# same as prices, but there have been added adjustments for splits.
# ----
# * **prices.csv**
# raw, as-is daily prices. Most of data spans from 2010 to the end 2016, for companies new on stock market date range is shorter. There have been approx. 140 stock splits in that time, this set doesn't account for that.
# ----
#
# [New York Stock Exchange Data]: <https://www.kaggle.com/dgawlik/nyse?select=prices.csv>

# %%
# Load Data
import pandas as pd

fundamentals = pd.read_csv(DATA_DIR + "/" + "fundamentals.csv", index_col=0)
securities   = pd.read_csv(DATA_DIR + "/" + "securities.csv")
prices       = pd.read_csv(DATA_DIR + "/" + "prices-split-adjusted.csv")
prices[prices["symbol"] == "MSFT"].head()
# Out:
#             date symbol       open      close        low       high  \
# 544   2010-01-04   MSFT  30.620001  30.950001  30.590000  31.100000
# 1012  2010-01-05   MSFT  30.850000  30.959999  30.639999  31.100000
# 1480  2010-01-06   MSFT  30.879999  30.770000  30.520000  31.080000
# 1948  2010-01-07   MSFT  30.629999  30.450001  30.190001  30.700001
# 1109       9.096000e+09               -1.380900e+10
# 1110       2.282000e+09               -1.530100e+10
#
#       Sales, General and Admin.  \
# 1107               2.028900e+10
# 1108               2.048800e+10
# 1109               2.032400e+10
# 1110               1.926000e+10
#
#       Short-Term Debt / Current Portion of Long-Term Debt  \
# 1107                                       2.999000e+09
# 1108                                       2.000000e+09
# 1109                                       7.484000e+09
# 1110                                       1.290400e+10
#
#       Short-Term Investments  Total Assets  Total Current Assets  \
# 1107            7.321800e+10  1.424310e+11          1.014660e+11
# 1108            7.704000e+10  1.723840e+11          1.142460e+11
# 1109            9.093100e+10  1.744720e+11          1.227970e+11
# 1110            1.067300e+11  1.936940e+11          1.396600e+11
#
#       Total Current Liabilities  Total Equity  Total Liabilities  \
# 1107               3.741700e+10  7.894400e+10       6.348700e+10
# 1108               4.562500e+10  8.978400e+10       8.260000e+10
# 1109               4.964700e+10  8.008300e+10       9.438900e+10
# 1110               5.935700e+10  7.199700e+10       1.216970e+11
#
#       Total Liabilities & Equity  Total Revenue  Treasury Stock  For Year  \
# 1107                1.424310e+11   7.784900e+10             0.0    2013.0
# 1108                1.723840e+11   8.683300e+10             0.0    2014.0
# 1109                1.744720e+11   9.358000e+10             0.0    2015.0
# 1110                1.936940e+11   8.532000e+10             0.0    2016.0
#
#       Earnings Per Share  Estimated Shares Outstanding
# 1107                2.61                  8.376628e+09
# 1108                2.66                  8.298496e+09
# 1109                1.49                  8.183221e+09
# 1110                2.12                  7.923585e+09

# %%
securities[securities["Ticker symbol"] == "MSFT"].head()
# Out:
#     Ticker symbol         Security SEC filings             GICS Sector  \
# 306          MSFT  Microsoft Corp.     reports  Information Technology
#
#     GICS Sub Industry Address of Headquarters Date first added     CIK
# 306  Systems Software     Redmond, Washington       1994-06-01  789019

# %% [markdown]
# # Selected stock indicators
# ____
# * __On-Balance Volume__ *(OBV)*
# Indicator of stock momentum based on close price and stock volume
# ____
# * __Accumulation/Distribution Index__ *(ADI)*
# money flow indicator considers stock volume as well as closing price in regard to price range.
# ____
# * __Aroon Indicator__ *(AI / AIU / AID)*
# Trend following indicator, describes strength of the current trend and likely hood that it will continue.
# May be divided into up and down indexes.
# ____
# * __Relative Strength Index__ *(RSI)*
# Measurement of the of price change magnitude, indicates overbought or oversold conditions in the price of a stock.
# ____
# * __Volume Weighted Average Price__ *(VWAP)*
# Average price calculated in regard to stock volume.
# ____
# * __Simple Moving Average 7 Days__ *(SMA7)*
# Moving average over 7 day period
# ____
# * __Simple Moving Average 14 Days__ *(SMA14)*
# Moving average over 14 day period
# ____

# %%
ticker = "MSFT"
stock_price = prices[prices["symbol"] == ticker]

# %%
OBV = ta.volume.on_balance_volume(stock_price["close"], stock_price["volume"])
fig = px.line(stock_price, x=stock_price["date"], y=OBV, labels=dict(y="On-Balance Volume"))
fig.update_layout(template="simple_white")
fig
# Out:
# <div>                            <div id="e8a9ab44-3c0e-4988-85a9-f1f0d7a84342" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8a9ab44-3c0e-4988-85a9-f1f0d7a84342")) {                    Plotly.newPlot(                        "e8a9ab44-3c0e-4988-85a9-f1f0d7a84342",                        [{"hovertemplate": "date=%{x}<br>On-Balance Volume=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2010-01-04", "2010-01-05", "2010-01-06", "2010-01-07", "2010-01-08", "2010-01-11", "2010-01-12", "2010-01-13", "2010-01-14", "2010-01-15", "2010-01-19", "2010-01-20", "2010-01-21", "2010-01-22", "2010-01-25", "2010-01-26", "2010-01-27", "2010-01-28", "2010-01-29", "2010-02-01", "2010-02-02", "2010-02-03", "2010-02-04", "2010-02-05", "2010-02-08", "2010-02-09", "2010-02-10", "2010-02-11", "2010-02-12", "2010-02-16", "2010-02-17", "2010-02-18", "2010-02-19", "2010-02-22", "2010-02-23", "2010-02-24", "2010-02-25", "2010-02-26", "2010-03-01", "2010-03-02", "2010-03-03", "2010-03-04", "2010-03-05", "2010-03-08", "2010-03-09", "2010-03-10", "2010-03-11", "2010-03-12", "2010-03-15", "2010-03-16", "2010-03-17", "2010-03-18", "2010-03-19", "2010-03-22", "2010-03-23", "2010-03-24", "2010-03-25", "2010-03-26", "2010-03-29", "2010-03-30", "2010-03-31", "2010-04-01", "2010-04-05", "2010-04-06", "2010-04-07", "2010-04-08", "2010-04-09", "2010-04-12", "2010-04-13", "2010-04-14", "2010-04-15", "2010-04-16", "2010-04-19", "2010-04-20", "2010-04-21", "2010-04-22", "2010-04-23", "2010-04-26", "2010-04-27", "2010-04-28", "2010-04-29", "2010-04-30", "2010-05-03", "2010-05-04", "2010-05-05", "2010-05-06", "2010-05-07", "2010-05-10", "2010-05-11", "2010-05-12", "2010-05-13", "2010-05-14", "2010-05-17", "2010-05-18", "2010-05-19", "2010-05-20", "2010-05-21", "2010-05-24", "2010-05-25", "2010-05-26", "2010-05-27", "2010-05-28", "2010-06-01", "2010-06-02", "2010-06-03", "2010-06-04", "2010-06-07", "2010-06-08", "2010-06-09", "2010-06-10", "2010-06-11", "2010-06-14", "2010-06-15", "2010-06-16", "2010-06-17", "2010-06-18", "2010-06-21", "2010-06-22", "2010-06-23", "2010-06-24", "2010-06-25", "2010-06-28", "2010-06-29", "2010-06-30", "2010-07-01", "2010-07-02", "2010-07-06", "2010-07-07", "2010-07-08", "2010-07-09", "2010-07-12", "2010-07-13", "2010-07-14", "2010-07-15", "2010-07-16", "2010-07-19", "2010-07-20", "2010-07-21", "2010-07-22", "2010-07-23", "2010-07-26", "2010-07-27", "2010-07-28", "2010-07-29", "2010-07-30", "2010-08-02", "2010-08-03", "2010-08-04", "2010-08-05", "2010-08-06", "2010-08-09", "2010-08-10", "2010-08-11", "2010-08-12", "2010-08-13", "2010-08-16", "2010-08-17", "2010-08-18", "2010-08-19", "2010-08-20", "2010-08-23", "2010-08-24", "2010-08-25", "2010-08-26", "2010-08-27", "2010-08-30", "2010-08-31", "2010-09-01", "2010-09-02", "2010-09-03", "2010-09-07", "2010-09-08", "2010-09-09", "2010-09-10", "2010-09-13", "2010-09-14", "2010-09-15", "2010-09-16", "2010-09-17", "2010-09-20", "2010-09-21", "2010-09-22", "2010-09-23", "2010-09-24", "2010-09-27", "2010-09-28", "2010-09-29", "2010-09-30", "2010-10-01", "2010-10-04", "2010-10-05", "2010-10-06", "2010-10-07", "2010-10-08", "2010-10-11", "2010-10-12", "2010-10-13", "2010-10-14", "2010-10-15", "2010-10-18", "2010-10-19", "2010-10-20", "2010-10-21", "2010-10-22", "2010-10-25", "2010-10-26", "2010-10-27", "2010-10-28", "2010-10-29", "2010-11-01", "2010-11-02", "2010-11-03", "2010-11-04", "2010-11-05", "2010-11-08", "2010-11-09", "2010-11-10", "2010-11-11", "2010-11-12", "2010-11-15", "2010-11-16", "2010-11-17", "2010-11-18", "2010-11-19", "2010-11-22", "2010-11-23", "2010-11-24", "2010-11-26", "2010-11-29", "2010-11-30", "2010-12-01", "2010-12-02", "2010- ...

# %%
indicator = ta.volume.AccDistIndexIndicator(stock_price["high"], stock_price["low"],
                                            stock_price["close"], stock_price["volume"])
ADI = indicator.acc_dist_index()
fig = px.line(stock_price, x=stock_price["date"], y=ADI, labels=dict(y="Accumulation & Distribution Index"))
fig.update_layout(template="simple_white")
fig
# Out:
# <div>                            <div id="07f1b63e-f77c-4856-93b0-fb3312121e8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07f1b63e-f77c-4856-93b0-fb3312121e8f")) {                    Plotly.newPlot(                        "07f1b63e-f77c-4856-93b0-fb3312121e8f",                        [{"hovertemplate": "date=%{x}<br>Accumulation & Distribution Index=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2010-01-04", "2010-01-05", "2010-01-06", "2010-01-07", "2010-01-08", "2010-01-11", "2010-01-12", "2010-01-13", "2010-01-14", "2010-01-15", "2010-01-19", "2010-01-20", "2010-01-21", "2010-01-22", "2010-01-25", "2010-01-26", "2010-01-27", "2010-01-28", "2010-01-29", "2010-02-01", "2010-02-02", "2010-02-03", "2010-02-04", "2010-02-05", "2010-02-08", "2010-02-09", "2010-02-10", "2010-02-11", "2010-02-12", "2010-02-16", "2010-02-17", "2010-02-18", "2010-02-19", "2010-02-22", "2010-02-23", "2010-02-24", "2010-02-25", "2010-02-26", "2010-03-01", "2010-03-02", "2010-03-03", "2010-03-04", "2010-03-05", "2010-03-08", "2010-03-09", "2010-03-10", "2010-03-11", "2010-03-12", "2010-03-15", "2010-03-16", "2010-03-17", "2010-03-18", "2010-03-19", "2010-03-22", "2010-03-23", "2010-03-24", "2010-03-25", "2010-03-26", "2010-03-29", "2010-03-30", "2010-03-31", "2010-04-01", "2010-04-05", "2010-04-06", "2010-04-07", "2010-04-08", "2010-04-09", "2010-04-12", "2010-04-13", "2010-04-14", "2010-04-15", "2010-04-16", "2010-04-19", "2010-04-20", "2010-04-21", "2010-04-22", "2010-04-23", "2010-04-26", "2010-04-27", "2010-04-28", "2010-04-29", "2010-04-30", "2010-05-03", "2010-05-04", "2010-05-05", "2010-05-06", "2010-05-07", "2010-05-10", "2010-05-11", "2010-05-12", "2010-05-13", "2010-05-14", "2010-05-17", "2010-05-18", "2010-05-19", "2010-05-20", "2010-05-21", "2010-05-24", "2010-05-25", "2010-05-26", "2010-05-27", "2010-05-28", "2010-06-01", "2010-06-02", "2010-06-03", "2010-06-04", "2010-06-07", "2010-06-08", "2010-06-09", "2010-06-10", "2010-06-11", "2010-06-14", "2010-06-15", "2010-06-16", "2010-06-17", "2010-06-18", "2010-06-21", "2010-06-22", "2010-06-23", "2010-06-24", "2010-06-25", "2010-06-28", "2010-06-29", "2010-06-30", "2010-07-01", "2010-07-02", "2010-07-06", "2010-07-07", "2010-07-08", "2010-07-09", "2010-07-12", "2010-07-13", "2010-07-14", "2010-07-15", "2010-07-16", "2010-07-19", "2010-07-20", "2010-07-21", "2010-07-22", "2010-07-23", "2010-07-26", "2010-07-27", "2010-07-28", "2010-07-29", "2010-07-30", "2010-08-02", "2010-08-03", "2010-08-04", "2010-08-05", "2010-08-06", "2010-08-09", "2010-08-10", "2010-08-11", "2010-08-12", "2010-08-13", "2010-08-16", "2010-08-17", "2010-08-18", "2010-08-19", "2010-08-20", "2010-08-23", "2010-08-24", "2010-08-25", "2010-08-26", "2010-08-27", "2010-08-30", "2010-08-31", "2010-09-01", "2010-09-02", "2010-09-03", "2010-09-07", "2010-09-08", "2010-09-09", "2010-09-10", "2010-09-13", "2010-09-14", "2010-09-15", "2010-09-16", "2010-09-17", "2010-09-20", "2010-09-21", "2010-09-22", "2010-09-23", "2010-09-24", "2010-09-27", "2010-09-28", "2010-09-29", "2010-09-30", "2010-10-01", "2010-10-04", "2010-10-05", "2010-10-06", "2010-10-07", "2010-10-08", "2010-10-11", "2010-10-12", "2010-10-13", "2010-10-14", "2010-10-15", "2010-10-18", "2010-10-19", "2010-10-20", "2010-10-21", "2010-10-22", "2010-10-25", "2010-10-26", "2010-10-27", "2010-10-28", "2010-10-29", "2010-11-01", "2010-11-02", "2010-11-03", "2010-11-04", "2010-11-05", "2010-11-08", "2010-11-09", "2010-11-10", "2010-11-11", "2010-11-12", "2010-11-15", "2010-11-16", "2010-11-17", "2010-11-18", "2010-11-19", "2010-11-22", "2010-11-23", "2010-11-24", "2010-11-26", "2010-11-29", "2010-11-30", "2010-12-01", "201 ...

# %%
indicator = ta.trend.AroonIndicator(stock_price["close"])
AI  = indicator.aroon_indicator()
AIU = indicator.aroon_up()
AID = indicator.aroon_down()

AI_df = pd.concat([stock_price["date"], AI], axis=1)
AI_df["name"] = "AI"
AI_df = AI_df.rename(columns={AI_df.columns[0]: "date", AI_df.columns[1]: "value"})
AIU_df = pd.concat([stock_price["date"], AIU], axis=1)
AIU_df["name"] = "AIU"
AIU_df = AIU_df.rename(columns={AIU_df.columns[1]: "date", AIU_df.columns[1]: "value"})
AID_df = pd.concat([stock_price["date"], AID], axis=1)
AID_df["name"] = "AID"
AID_df = AID_df.rename(columns={AID_df.columns[1]: "date", AID_df.columns[1]: "value"})
AI_df = AI_df.append([AIU_df, AID_df])

fig = px.line(AI_df, x="date", y="value", color="name")
fig.update_layout(template="simple_white")
fig
# Out:
# <div>                            <div id="d7d921bd-4a8c-41f3-b488-5b50b6de3e5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7d921bd-4a8c-41f3-b488-5b50b6de3e5d")) {                    Plotly.newPlot(                        "d7d921bd-4a8c-41f3-b488-5b50b6de3e5d",                        [{"hovertemplate": "name=AI<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "AI", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "AI", "showlegend": true, "type": "scattergl", "x": ["2010-01-04", "2010-01-05", "2010-01-06", "2010-01-07", "2010-01-08", "2010-01-11", "2010-01-12", "2010-01-13", "2010-01-14", "2010-01-15", "2010-01-19", "2010-01-20", "2010-01-21", "2010-01-22", "2010-01-25", "2010-01-26", "2010-01-27", "2010-01-28", "2010-01-29", "2010-02-01", "2010-02-02", "2010-02-03", "2010-02-04", "2010-02-05", "2010-02-08", "2010-02-09", "2010-02-10", "2010-02-11", "2010-02-12", "2010-02-16", "2010-02-17", "2010-02-18", "2010-02-19", "2010-02-22", "2010-02-23", "2010-02-24", "2010-02-25", "2010-02-26", "2010-03-01", "2010-03-02", "2010-03-03", "2010-03-04", "2010-03-05", "2010-03-08", "2010-03-09", "2010-03-10", "2010-03-11", "2010-03-12", "2010-03-15", "2010-03-16", "2010-03-17", "2010-03-18", "2010-03-19", "2010-03-22", "2010-03-23", "2010-03-24", "2010-03-25", "2010-03-26", "2010-03-29", "2010-03-30", "2010-03-31", "2010-04-01", "2010-04-05", "2010-04-06", "2010-04-07", "2010-04-08", "2010-04-09", "2010-04-12", "2010-04-13", "2010-04-14", "2010-04-15", "2010-04-16", "2010-04-19", "2010-04-20", "2010-04-21", "2010-04-22", "2010-04-23", "2010-04-26", "2010-04-27", "2010-04-28", "2010-04-29", "2010-04-30", "2010-05-03", "2010-05-04", "2010-05-05", "2010-05-06", "2010-05-07", "2010-05-10", "2010-05-11", "2010-05-12", "2010-05-13", "2010-05-14", "2010-05-17", "2010-05-18", "2010-05-19", "2010-05-20", "2010-05-21", "2010-05-24", "2010-05-25", "2010-05-26", "2010-05-27", "2010-05-28", "2010-06-01", "2010-06-02", "2010-06-03", "2010-06-04", "2010-06-07", "2010-06-08", "2010-06-09", "2010-06-10", "2010-06-11", "2010-06-14", "2010-06-15", "2010-06-16", "2010-06-17", "2010-06-18", "2010-06-21", "2010-06-22", "2010-06-23", "2010-06-24", "2010-06-25", "2010-06-28", "2010-06-29", "2010-06-30", "2010-07-01", "2010-07-02", "2010-07-06", "2010-07-07", "2010-07-08", "2010-07-09", "2010-07-12", "2010-07-13", "2010-07-14", "2010-07-15", "2010-07-16", "2010-07-19", "2010-07-20", "2010-07-21", "2010-07-22", "2010-07-23", "2010-07-26", "2010-07-27", "2010-07-28", "2010-07-29", "2010-07-30", "2010-08-02", "2010-08-03", "2010-08-04", "2010-08-05", "2010-08-06", "2010-08-09", "2010-08-10", "2010-08-11", "2010-08-12", "2010-08-13", "2010-08-16", "2010-08-17", "2010-08-18", "2010-08-19", "2010-08-20", "2010-08-23", "2010-08-24", "2010-08-25", "2010-08-26", "2010-08-27", "2010-08-30", "2010-08-31", "2010-09-01", "2010-09-02", "2010-09-03", "2010-09-07", "2010-09-08", "2010-09-09", "2010-09-10", "2010-09-13", "2010-09-14", "2010-09-15", "2010-09-16", "2010-09-17", "2010-09-20", "2010-09-21", "2010-09-22", "2010-09-23", "2010-09-24", "2010-09-27", "2010-09-28", "2010-09-29", "2010-09-30", "2010-10-01", "2010-10-04", "2010-10-05", "2010-10-06", "2010-10-07", "2010-10-08", "2010-10-11", "2010-10-12", "2010-10-13", "2010-10-14", "2010-10-15", "2010-10-18", "2010-10-19", "2010-10-20", "2010-10-21", "2010-10-22", "2010-10-25", "2010-10-26", "2010-10-27", "2010-10-28", "2010-10-29", "2010-11-01", "2010-11-02", "2010-11-03", "2010-11-04", "2010-11-05", "2010-11-08", "2010-11-09", "2010-11-10", "2010-11-11", "2010-11-12", "2010-11-15", "2010-11-16", "2010-11-17", "2010-11-18", "2010-11-19", "2010-11-22", "2010-11-23", "2010-11-24", "2010-11-26", "2010-11-29", "2010-11-30", "2010-12-01", "2010-12-02", "201 ...

# %%
indicator = ta.momentum.RSIIndicator(close=stock_price["close"], window=14)
RSI = indicator.rsi()

fig = px.line(stock_price, x=stock_price["date"], y=RSI, labels=dict(y="Relative Strength Index"))
fig.update_layout(template="simple_white")
fig
# Out:
# <div>                            <div id="9d9959b6-099f-4269-8e4a-3cd2fc5afb41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d9959b6-099f-4269-8e4a-3cd2fc5afb41")) {                    Plotly.newPlot(                        "9d9959b6-099f-4269-8e4a-3cd2fc5afb41",                        [{"hovertemplate": "date=%{x}<br>Relative Strength Index=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2010-01-04", "2010-01-05", "2010-01-06", "2010-01-07", "2010-01-08", "2010-01-11", "2010-01-12", "2010-01-13", "2010-01-14", "2010-01-15", "2010-01-19", "2010-01-20", "2010-01-21", "2010-01-22", "2010-01-25", "2010-01-26", "2010-01-27", "2010-01-28", "2010-01-29", "2010-02-01", "2010-02-02", "2010-02-03", "2010-02-04", "2010-02-05", "2010-02-08", "2010-02-09", "2010-02-10", "2010-02-11", "2010-02-12", "2010-02-16", "2010-02-17", "2010-02-18", "2010-02-19", "2010-02-22", "2010-02-23", "2010-02-24", "2010-02-25", "2010-02-26", "2010-03-01", "2010-03-02", "2010-03-03", "2010-03-04", "2010-03-05", "2010-03-08", "2010-03-09", "2010-03-10", "2010-03-11", "2010-03-12", "2010-03-15", "2010-03-16", "2010-03-17", "2010-03-18", "2010-03-19", "2010-03-22", "2010-03-23", "2010-03-24", "2010-03-25", "2010-03-26", "2010-03-29", "2010-03-30", "2010-03-31", "2010-04-01", "2010-04-05", "2010-04-06", "2010-04-07", "2010-04-08", "2010-04-09", "2010-04-12", "2010-04-13", "2010-04-14", "2010-04-15", "2010-04-16", "2010-04-19", "2010-04-20", "2010-04-21", "2010-04-22", "2010-04-23", "2010-04-26", "2010-04-27", "2010-04-28", "2010-04-29", "2010-04-30", "2010-05-03", "2010-05-04", "2010-05-05", "2010-05-06", "2010-05-07", "2010-05-10", "2010-05-11", "2010-05-12", "2010-05-13", "2010-05-14", "2010-05-17", "2010-05-18", "2010-05-19", "2010-05-20", "2010-05-21", "2010-05-24", "2010-05-25", "2010-05-26", "2010-05-27", "2010-05-28", "2010-06-01", "2010-06-02", "2010-06-03", "2010-06-04", "2010-06-07", "2010-06-08", "2010-06-09", "2010-06-10", "2010-06-11", "2010-06-14", "2010-06-15", "2010-06-16", "2010-06-17", "2010-06-18", "2010-06-21", "2010-06-22", "2010-06-23", "2010-06-24", "2010-06-25", "2010-06-28", "2010-06-29", "2010-06-30", "2010-07-01", "2010-07-02", "2010-07-06", "2010-07-07", "2010-07-08", "2010-07-09", "2010-07-12", "2010-07-13", "2010-07-14", "2010-07-15", "2010-07-16", "2010-07-19", "2010-07-20", "2010-07-21", "2010-07-22", "2010-07-23", "2010-07-26", "2010-07-27", "2010-07-28", "2010-07-29", "2010-07-30", "2010-08-02", "2010-08-03", "2010-08-04", "2010-08-05", "2010-08-06", "2010-08-09", "2010-08-10", "2010-08-11", "2010-08-12", "2010-08-13", "2010-08-16", "2010-08-17", "2010-08-18", "2010-08-19", "2010-08-20", "2010-08-23", "2010-08-24", "2010-08-25", "2010-08-26", "2010-08-27", "2010-08-30", "2010-08-31", "2010-09-01", "2010-09-02", "2010-09-03", "2010-09-07", "2010-09-08", "2010-09-09", "2010-09-10", "2010-09-13", "2010-09-14", "2010-09-15", "2010-09-16", "2010-09-17", "2010-09-20", "2010-09-21", "2010-09-22", "2010-09-23", "2010-09-24", "2010-09-27", "2010-09-28", "2010-09-29", "2010-09-30", "2010-10-01", "2010-10-04", "2010-10-05", "2010-10-06", "2010-10-07", "2010-10-08", "2010-10-11", "2010-10-12", "2010-10-13", "2010-10-14", "2010-10-15", "2010-10-18", "2010-10-19", "2010-10-20", "2010-10-21", "2010-10-22", "2010-10-25", "2010-10-26", "2010-10-27", "2010-10-28", "2010-10-29", "2010-11-01", "2010-11-02", "2010-11-03", "2010-11-04", "2010-11-05", "2010-11-08", "2010-11-09", "2010-11-10", "2010-11-11", "2010-11-12", "2010-11-15", "2010-11-16", "2010-11-17", "2010-11-18", "2010-11-19", "2010-11-22", "2010-11-23", "2010-11-24", "2010-11-26", "2010-11-29", "2010-11-30", "2010-12-01", "2010-12-02",  ...

# %%
indicator = ta.volume.VolumeWeightedAveragePrice(stock_price["high"], stock_price["low"], 
                                     stock_price["close"],stock_price["volume"], window=14)
VWAP = indicator.volume_weighted_average_price()

indicator = ta.trend.SMAIndicator(stock_price["close"], window=7)
SMA7 = indicator.sma_indicator()

indicator = ta.trend.SMAIndicator(stock_price["close"], window=14)
SMA14 = indicator.sma_indicator()

VMAP_df = pd.concat([stock_price["date"], VWAP], axis=1)
VMAP_df["name"] = "VWAP"
VMAP_df = VMAP_df.rename(columns={VMAP_df.columns[0]: "date", VMAP_df.columns[1]: "value"})
SMA7_df = pd.concat([stock_price["date"], SMA7], axis=1)
SMA7_df["name"] = "SMA7"
SMA7_df = SMA7_df.rename(columns={SMA7_df.columns[1]: "date", SMA7_df.columns[1]: "value"})
SMA14_df = pd.concat([stock_price["date"], SMA14], axis=1)
SMA14_df["name"] = "SMA14"
SMA14_df = SMA14_df.rename(columns={SMA14_df.columns[1]: "date", SMA14_df.columns[1]: "value"})
VMAP_df = VMAP_df.append([SMA7_df, SMA14_df])

fig = px.line(VMAP_df, x="date", y="value", color="name")
fig.update_layout(template="simple_white")
fig
# Out:
# <div>                            <div id="fdf8a578-1b35-472d-b791-9e4cec169f91" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fdf8a578-1b35-472d-b791-9e4cec169f91")) {                    Plotly.newPlot(                        "fdf8a578-1b35-472d-b791-9e4cec169f91",                        [{"hovertemplate": "name=VWAP<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "VWAP", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "VWAP", "showlegend": true, "type": "scattergl", "x": ["2010-01-04", "2010-01-05", "2010-01-06", "2010-01-07", "2010-01-08", "2010-01-11", "2010-01-12", "2010-01-13", "2010-01-14", "2010-01-15", "2010-01-19", "2010-01-20", "2010-01-21", "2010-01-22", "2010-01-25", "2010-01-26", "2010-01-27", "2010-01-28", "2010-01-29", "2010-02-01", "2010-02-02", "2010-02-03", "2010-02-04", "2010-02-05", "2010-02-08", "2010-02-09", "2010-02-10", "2010-02-11", "2010-02-12", "2010-02-16", "2010-02-17", "2010-02-18", "2010-02-19", "2010-02-22", "2010-02-23", "2010-02-24", "2010-02-25", "2010-02-26", "2010-03-01", "2010-03-02", "2010-03-03", "2010-03-04", "2010-03-05", "2010-03-08", "2010-03-09", "2010-03-10", "2010-03-11", "2010-03-12", "2010-03-15", "2010-03-16", "2010-03-17", "2010-03-18", "2010-03-19", "2010-03-22", "2010-03-23", "2010-03-24", "2010-03-25", "2010-03-26", "2010-03-29", "2010-03-30", "2010-03-31", "2010-04-01", "2010-04-05", "2010-04-06", "2010-04-07", "2010-04-08", "2010-04-09", "2010-04-12", "2010-04-13", "2010-04-14", "2010-04-15", "2010-04-16", "2010-04-19", "2010-04-20", "2010-04-21", "2010-04-22", "2010-04-23", "2010-04-26", "2010-04-27", "2010-04-28", "2010-04-29", "2010-04-30", "2010-05-03", "2010-05-04", "2010-05-05", "2010-05-06", "2010-05-07", "2010-05-10", "2010-05-11", "2010-05-12", "2010-05-13", "2010-05-14", "2010-05-17", "2010-05-18", "2010-05-19", "2010-05-20", "2010-05-21", "2010-05-24", "2010-05-25", "2010-05-26", "2010-05-27", "2010-05-28", "2010-06-01", "2010-06-02", "2010-06-03", "2010-06-04", "2010-06-07", "2010-06-08", "2010-06-09", "2010-06-10", "2010-06-11", "2010-06-14", "2010-06-15", "2010-06-16", "2010-06-17", "2010-06-18", "2010-06-21", "2010-06-22", "2010-06-23", "2010-06-24", "2010-06-25", "2010-06-28", "2010-06-29", "2010-06-30", "2010-07-01", "2010-07-02", "2010-07-06", "2010-07-07", "2010-07-08", "2010-07-09", "2010-07-12", "2010-07-13", "2010-07-14", "2010-07-15", "2010-07-16", "2010-07-19", "2010-07-20", "2010-07-21", "2010-07-22", "2010-07-23", "2010-07-26", "2010-07-27", "2010-07-28", "2010-07-29", "2010-07-30", "2010-08-02", "2010-08-03", "2010-08-04", "2010-08-05", "2010-08-06", "2010-08-09", "2010-08-10", "2010-08-11", "2010-08-12", "2010-08-13", "2010-08-16", "2010-08-17", "2010-08-18", "2010-08-19", "2010-08-20", "2010-08-23", "2010-08-24", "2010-08-25", "2010-08-26", "2010-08-27", "2010-08-30", "2010-08-31", "2010-09-01", "2010-09-02", "2010-09-03", "2010-09-07", "2010-09-08", "2010-09-09", "2010-09-10", "2010-09-13", "2010-09-14", "2010-09-15", "2010-09-16", "2010-09-17", "2010-09-20", "2010-09-21", "2010-09-22", "2010-09-23", "2010-09-24", "2010-09-27", "2010-09-28", "2010-09-29", "2010-09-30", "2010-10-01", "2010-10-04", "2010-10-05", "2010-10-06", "2010-10-07", "2010-10-08", "2010-10-11", "2010-10-12", "2010-10-13", "2010-10-14", "2010-10-15", "2010-10-18", "2010-10-19", "2010-10-20", "2010-10-21", "2010-10-22", "2010-10-25", "2010-10-26", "2010-10-27", "2010-10-28", "2010-10-29", "2010-11-01", "2010-11-02", "2010-11-03", "2010-11-04", "2010-11-05", "2010-11-08", "2010-11-09", "2010-11-10", "2010-11-11", "2010-11-12", "2010-11-15", "2010-11-16", "2010-11-17", "2010-11-18", "2010-11-19", "2010-11-22", "2010-11-23", "2010-11-24", "2010-11-26", "2010-11-29", "2010-11-30", "2010-12-01", "2010-12-02" ...

# %%
indicators = pd.DataFrame()
indicators["OBV"] = OBV
indicators["ADI"] = ADI
indicators["AI"] = AI
# indicators["AID"] = AID
# indicators["AIU"] = AIU
indicators["VWAP"] = VWAP
# indicators["SMA7"] = SMA7
# indicators["SMA14"] = SMA14
indicators["close"] = stock_price["close"]

indicators = indicators.dropna()
indicators.head()
# Out:
#                OBV           ADI    AI       VWAP      close
# 11776 -217647100.0 -1.845589e+08 -56.0  28.918897  27.719999
# 12244 -158451300.0 -1.915822e+08 -56.0  28.792828  28.010000
# 12712 -207042600.0 -2.037300e+08 -56.0  28.665757  27.990000
# 13180 -141048900.0 -1.905311e+08 -56.0  28.567642  28.120001
# 13648 -222166100.0 -1.533522e+08 -56.0  28.470470  27.930000

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
transformer = MinMaxScaler().fit(indicators)
scaled_indicators = pd.DataFrame(transformer.transform(indicators), columns=indicators.columns)
scaled_indicators.head()
# Out:
#         OBV       ADI        AI      VWAP     close
# 0  0.821259  0.147287  0.208333  0.127246  0.115981
# 1  0.839087  0.145149  0.208333  0.124011  0.123122
# 2  0.824453  0.141451  0.208333  0.120751  0.122630
# 3  0.844328  0.145469  0.208333  0.118234  0.125831
# 4  0.819898  0.156788  0.208333  0.115741  0.121152

# %%
sequence_length = 14
predicted_values = ["close"]

train_data_length = (0, round(0.7 * scaled_indicators.shape[0]))
val_data_length = (round(0.7 * scaled_indicators.shape[0])+1, round(0.9 * scaled_indicators.shape[0]))
test_data_length = (round(0.9 * scaled_indicators.shape[0])+1, scaled_indicators.shape[0])

train_x = generate_input_sequences(data=scaled_indicators[train_data_length[0]:train_data_length[1]],
                                   input_length=sequence_length)
train_y = generate_output_sequences(data=scaled_indicators[train_data_length[0]:train_data_length[1]],
                                    input_length=sequence_length, outputs=predicted_values)

val_x = generate_input_sequences(data=scaled_indicators[val_data_length[0]:val_data_length[1]],
                                 input_length=sequence_length)
val_y = generate_output_sequences(data=scaled_indicators[val_data_length[0]:val_data_length[1]],
                                  input_length=sequence_length, outputs=predicted_values)

test_x = generate_input_sequences(data=scaled_indicators[test_data_length[0]:test_data_length[1]],
                                  input_length=sequence_length)
test_y = generate_output_sequences(data=scaled_indicators[test_data_length[0]:test_data_length[1]],
                                   input_length=sequence_length, outputs=predicted_values)

print(f"Train_x: {train_x.shape}")
print(f"Train_y: {train_y.shape}")
print("---------------------------------")
print(f"Val_x:   {val_x.shape}")
print(f"Val_y:   {val_y.shape}")
print("---------------------------------")
print(f"Test_x:  {test_x.shape}")
print(f"Test_y:  {test_y.shape}")
# Out:
# Train_x: (1202, 14, 6)
# Train_y: (1202, 1)
# ---------------------------------
# Val_x:   (331, 14, 6)
# Val_y:   (331, 1)
# ---------------------------------
# Test_x:  (158, 14, 6)
# Test_y:  (158, 1)

# %%
epochs = 40
batch_size = 64

# %%
import keras
from keras import models
from keras import layers
from keras import metrics

model_name = "First Model"

model = models.Sequential(name=model_name)

model.add(layers.LSTM(units=50, activation="relu", name="LSTM_1", dropout=0.05, 
                      input_shape=(train_x.shape[1], train_x.shape[2]), 
                      return_sequences=True))

model.add(layers.LSTM(units=100, activation="relu", name="LSTM_2", dropout=0.1))

model.add(layers.Dense(units=200, activation="relu", name="Dense_1"))
model.add(layers.Dropout(0.15, name="Dropout_1"))

model.add(layers.Dense(units=400, activation="relu", name="Dense_2"))
model.add(layers.Dropout(0.25, name="Dropout_2"))

model.add(layers.Dense(units=50, activation="relu", name="Dense_3"))

model.add(layers.Dense(1, activation="tanh", name="classifier"))

model.compile(optimizer="Adam", 
              loss="mae", 
              metrics=["mean_absolute_percentage_error"])
model.summary()

history =  model.fit(train_x, train_y,
                     epochs=epochs,
                     batch_size=batch_size, 
                     validation_data=(val_x, val_y))


model_save_name = next_free_model_name(model_name)
model_save_path = MODELS_DIR + "/" + model_save_name + ".h5"
model.save(model_save_path)

history_save_path = MODELS_DIR + "/" + model_save_name + ".csv"
history_dataframe = pd.DataFrame(history.history)
history_dataframe.to_csv(history_save_path)
# Out:
# Using TensorFlow backend.
# Model: "First Model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM_1 (LSTM)                (None, 14, 50)            11400
# _________________________________________________________________
# LSTM_2 (LSTM)                (None, 100)               60400
# _________________________________________________________________
# Dense_1 (Dense)              (None, 200)               20200
# _________________________________________________________________
# Dropout_1 (Dropout)          (None, 200)               0
# _________________________________________________________________
# Dense_2 (Dense)              (None, 400)               80400
# _________________________________________________________________
# Dropout_2 (Dropout)          (None, 400)               0
# _________________________________________________________________
# Dense_3 (Dense)              (None, 50)                20050
# _________________________________________________________________
# classifier (Dense)           (None, 1)                 51
# =================================================================
# Total params: 192,501
# Trainable params: 192,501
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1202 samples, validate on 331 samples
# Epoch 1/40
# 1202/1202 [==============================] - 2s 2ms/step - loss: 0.0939 - mean_absolute_percentage_error: 64443.8672 - val_loss: 0.0670 - val_mean_absolute_percentage_error: 10.4817: 0.1058 - mean_absolute_percentage_error: 80680. - ETA: 0s - loss: 0.0990 - mean_absolute_percentage_error: 71192.68
# Epoch 2/40
# 1202/1202 [==============================] - 1s 836us/step - loss: 0.0427 - mean_absolute_percentage_error: 62087.1953 - val_loss: 0.0906 - val_mean_absolute_percentage_error: 14.0379
# Epoch 3/40
# 1202/1202 [==============================] - 1s 848us/step - loss: 0.0362 - mean_absolute_percentage_error: 56831.1406 - val_loss: 0.0882 - val_mean_absolute_percentage_error: 13.5774
# Epoch 4/40
# 1202/1202 [==============================] - 1s 832us/step - loss: 0.0333 - mean_absolute_percentage_error: 46607.4883 - val_loss: 0.0447 - val_mean_absolute_percentage_error: 6.8849
# Epoch 5/40
# 1202/1202 [==============================] - 1s 857us/step - loss: 0.0326 - mean_absolute_percentage_error: 45089.3750 - val_loss: 0.0453 - val_mean_absolute_percentage_error: 6.9150
# Epoch 6/40
# 1202/1202 [==============================] - 1s 832us/step - loss: 0.0297 - mean_absolute_percentage_error: 51833.5703 - val_loss: 0.0517 - val_mean_absolute_percentage_error: 7.8133
# Epoch 7/40
# 1202/1202 [==============================] - 1s 807us/step - loss: 0.0303 - mean_absolute_percentage_error: 48542.1562 - val_loss: 0.0427 - val_mean_absolute_percentage_error: 6.5440
# Epoch 8/40
# 1202/1202 [==============================] - 1s 799us/step - loss: 0.0277 - mean_absolute_percentage_error: 46214.1914 - val_loss: 0.0613 - val_mean_absolute_percentage_error: 9.2537
# Epoch 9/40
# 1202/1202 [==============================] - 1s 815us/step - loss: 0.0256 - mean_absolute_percentage_error: 40020.6367 - val_loss: 0.0566 - val_mean_absolute_percentage_error: 8.5355
# Epoch 10/40
# 1202/1202 [==============================] - 1s 873us/step - loss: 0.0285 - mean_absolute_percentage_error: 37752.3203 - val_loss: 0.1208 - val_mean_absolute_percentage_error: 18.8414
# Epoch 11/40
# 1202/1202 [==============================] - 1s 841us/step - loss: 0.0277 - mean_absolute_percentage_error: 53775.4648 - val_loss: 0.0451 - val_mean_absolute_percentage_error: 6.8573
# Epoch 12/40
# 1202/1202 [==============================] - 1s 807us/step - loss: 0.0268 - mean_absolute_percentage_error: 50819.5430 - val_loss: 0.0950 - val_mean_absolute_percentage_error: 14.7719
# Epoch 13/40
# 1202/1202 [==============================] - 1s 807us/step - loss: 0.0265 - mean_absolute_percentage_error: 58416.8242 - val_loss: 0.0523 - val_mean_absolute_percentage_error: 7.9340
# Epoch 14/40
# 1202/1202 [==============================] - 1s 815us/step - loss: 0.0251 - mean_absolute_percentage_error: 70077.6016 - val_loss: 0.0663 - val_mean_absolute_percentage_error: 9.9322ETA: 0s - loss: 0.0251 - mean_absolute_percentage_error: 1012
# Epoch 15/40
# 1202/1202 [==============================] - 1s 823us/step - loss: 0.0256 - mean_absolute_percentage_error: 51001.1484 - val_loss: 0.0866 - val_mean_absolute_percentage_error: 13.3767
# Epoch 16/40
# 1202/1202 [==============================] - 1s 807us/step - loss: 0.0237 - mean_absolute_percentage_error: 44042.7344 - val_loss: 0.0449 - val_mean_absolute_percentage_error: 6.8205
# Epoch 17/40
# 1202/1202 [==============================] - 1s 832us/step - loss: 0.0237 - mean_absolute_percentage_error: 51360.4883 - val_loss: 0.0574 - val_mean_absolute_percentage_error: 8.6832
# Epoch 18/40
# 1202/1202 [==============================] - 1s 815us/step - loss: 0.0237 - mean_absolute_percentage_error: 48309.5156 - val_loss: 0.0690 - val_mean_absolute_percentage_error: 10.4251
# Epoch 19/40
# 1202/1202 [==============================] - 1s 857us/step - loss: 0.0237 - mean_absolute_percentage_error: 41279.1328 - val_loss: 0.0580 - val_mean_absolute_percentage_error: 8.8060
# Epoch 20/40
# 1202/1202 [==============================] - 1s 807us/step - loss: 0.0230 - mean_absolute_percentage_error: 35195.5625 - val_loss: 0.0647 - val_mean_absolute_percentage_error: 9.9221
# Epoch 21/40
# 1202/1202 [==============================] - 1s 807us/step - loss: 0.0230 - mean_absolute_percentage_error: 49905.0508 - val_loss: 0.0519 - val_mean_absolute_percentage_error: 7.8357
# Epoch 22/40
# 1202/1202 [==============================] - 1s 824us/step - loss: 0.0226 - mean_absolute_percentage_error: 30843.2910 - val_loss: 0.0458 - val_mean_absolute_percentage_error: 6.9267
# Epoch 23/40
# 1202/1202 [==============================] - 1s 824us/step - loss: 0.
40
# 1202/1202 [==============================] - 1s 807us/step - loss: 0.0197 - mean_absolute_percentage_error: 47166.6172 - val_loss: 0.0595 - val_mean_absolute_percentage_error: 9.0284
# Epoch 40/40
# 1202/1202 [==============================] - 1s 807us/step - loss: 0.0207 - mean_absolute_percentage_error: 41336.5547 - val_loss: 0.0501 - val_mean_absolute_percentage_error: 7.5102

# %%
from sklearn.preprocessing import MaxAbsScaler, MinMaxScaler

predictions = model.predict(test_x)

scaler = MinMaxScaler().fit(indicators["close"].to_numpy().reshape(-1,1))
unscaled_predictions = scaler.inverse_transform(predictions)
unscaled_test_data = scaler.inverse_transform(test_y)
plt.plot(np.arange(len(predictions)), unscaled_predictions, label="Guess")
plt.plot(np.arange(len(predictions)), unscaled_test_data, label="Test")
plt.legend()
plt.show()

# %% [markdown]
# ## Model overfitted
# Solution to this problem is expandint data to more companies, which will allow the model to generalize much better

# %%
import ta
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler

company_data = []
keys = prices.symbol.unique()
for ticker in keys[:10]:
    stock_price = prices[prices["symbol"] == ticker]
    OBV = ta.volume.on_balance_volume(stock_price["close"], stock_price["volume"])
    
    indicator = ta.volume.AccDistIndexIndicator(stock_price["high"], stock_price["low"],
                                            stock_price["close"], stock_price["volume"])
    ADI = indicator.acc_dist_index()
    
    indicator = ta.trend.AroonIndicator(stock_price["close"])
    AI  = indicator.aroon_indicator()
    
    indicator = ta.momentum.RSIIndicator(close=stock_price["close"], window=14)
    RSI = indicator.rsi()
    
    indicator = ta.volume.VolumeWeightedAveragePrice(stock_price["high"], stock_price["low"], 
                                     stock_price["close"],stock_price["volume"], window=14)
    VWAP = indicator.volume_weighted_average_price()
    
    new_indicators = pd.DataFrame()
    new_indicators["OBV"] = OBV
    new_indicators["ADI"] = ADI
    new_indicators["AI"] = AI
    new_indicators["VWAP"] = VWAP
    new_indicators["close"] = stock_price["close"]
    new_indicators = new_indicators.dropna()
    new_indicators = new_indicators.to_numpy()
    
    company_data.append(new_indicators)

np.array(company_data, dtype=object)

max_price = max([np.max(company[:,-1]) for company in company_data])

# %%
max_price
# Out:
# 339.5

# %%
    data_scaler = MinMaxScaler().fit(new_indicatros)
    scaled_new_indicators = pd.DataFrame(data_scaler.transform(new_indicatros), columns=new_indicatros.columns)
    scaled_indicators = scaled_indicators.append(scaled_new_indicators)

# %% [markdown]
# ### Split data into 3d array to avoid generating input data from multiple companies as one input

# %%
sequence_length = 14
predicted_values = ["close"]

train_data_length = (0, round(0.7 * scaled_indicators.shape[0]))
val_data_length = (round(0.7 * scaled_indicators.shape[0])+1, round(0.9 * scaled_indicators.shape[0]))
test_data_length = (round(0.9 * scaled_indicators.shape[0])+1, scaled_indicators.shape[0])

train_x = generate_input_sequences(data=scaled_indicators[train_data_length[0]:train_data_length[1]],
                                   input_length=sequence_length)
train_y = generate_output_sequences(data=scaled_indicators[train_data_length[0]:train_data_length[1]],
                                    input_length=sequence_length, outputs=predicted_values)

val_x = generate_input_sequences(data=scaled_indicators[val_data_length[0]:val_data_length[1]],
                                 input_length=sequence_length)
val_y = generate_output_sequences(data=scaled_indicators[val_data_length[0]:val_data_length[1]],
                                  input_length=sequence_length, outputs=predicted_values)

test_x = generate_input_sequences(data=scaled_indicators[test_data_length[0]:test_data_length[1]],
                                  input_length=sequence_length)
test_y = generate_output_sequences(data=scaled_indicators[test_data_length[0]:test_data_length[1]],
                                   input_length=sequence_length, outputs=predicted_values)

print(f"Train_x: {train_x.shape}")
print(f"Train_y: {train_y.shape}")
print("---------------------------------")
print(f"Val_x:   {val_x.shape}")
print(f"Val_y:   {val_y.shape}")
print("---------------------------------")
print(f"Test_x:  {test_x.shape}")
print(f"Test_y:  {test_y.shape}")
# Out:
# Train_x: (120587, 14, 5)
# Train_y: (120587, 1)
# ---------------------------------
# Val_x:   (34442, 14, 5)
# Val_y:   (34442, 1)
# ---------------------------------
# Test_x:  (17213, 14, 5)
# Test_y:  (17213, 1)

# %%
epochs = 40
batch_size = 512

# %%
import keras
from keras import models
from keras import layers
from keras import metrics

model_name = "Second Model"

model = models.Sequential(name=model_name)

model.add(layers.LSTM(units=50, activation="relu", name="LSTM_1", dropout=0.05, 
                      input_shape=(train_x.shape[1], train_x.shape[2]), 
                      return_sequences=True))

model.add(layers.LSTM(units=100, activation="relu", name="LSTM_2", dropout=0.1))

model.add(layers.Dense(units=200, activation="relu", name="Dense_1"))
model.add(layers.Dropout(0.15, name="Dropout_1"))

model.add(layers.Dense(units=400, activation="relu", name="Dense_2"))
model.add(layers.Dropout(0.25, name="Dropout_2"))

model.add(layers.Dense(units=50, activation="relu", name="Dense_3"))

model.add(layers.Dense(1, activation="tanh", name="classifier"))

model.compile(optimizer="Adam", 
              loss="mae", 
              metrics=["mean_absolute_percentage_error"])
model.summary()

history =  model.fit(train_x, train_y,
                     epochs=epochs,
                     batch_size=batch_size, 
                     validation_data=(val_x, val_y))

model_save_name = next_free_model_name(model_name)
model_save_path = MODELS_DIR + "/" + model_save_name + ".h5"
model.save(model_save_path)

history_save_path = MODELS_DIR + "/" + model_save_name + ".csv"
history_dataframe = pd.DataFrame(history.history)
history_dataframe.to_csv(history_save_path)
# Out:
# Model: "Second Model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM_1 (LSTM)                (None, 14, 50)            11200
# _________________________________________________________________
# LSTM_2 (LSTM)                (None, 100)               60400
# _________________________________________________________________
# Dense_1 (Dense)              (None, 200)               20200
# _________________________________________________________________
# Dropout_1 (Dropout)          (None, 200)               0
# _________________________________________________________________
# Dense_2 (Dense)              (None, 400)               80400
# _________________________________________________________________
# Dropout_2 (Dropout)          (None, 400)               0
# _________________________________________________________________
# Dense_3 (Dense)              (None, 50)                20050
# _________________________________________________________________
# classifier (Dense)           (None, 1)                 51
# =================================================================
# Total params: 192,301
# Trainable params: 192,301
# Non-trainable params: 0
# _________________________________________________________________
# Train on 120587 samples, validate on 34442 samples
# Epoch 1/40
# 120587/120587 [==============================] - 13s 108us/step - loss: 0.0564 - mean_absolute_percentage_error: 146247.1719 - val_loss: 0.0610 - val_mean_absolute_percentage_error: 113190.1797 0.2544 - mean_absolute - ETA: 13s - loss: 0.1494 - mean_absolute_perce - ETA: 10s - loss: 0.1194 - - ETA: 7s - loss: 0.0825 - mean_absolute_percentage_error: 190910.0 - ETA: 6s - loss: 0.0809 - mean_absolu - ETA: 4s
40
# 120587/120587 [==============================] - 12s 102us/step - loss: 0.0148 - mean_absolute_percentage_error: 98327.8125 - val_loss: 0.0579 - val_mean_absolute_percentage_error: 98034.6328ean_absolute_percentage_error: 106 - ETA: 4s - loss: 0.0 - ETA: 3s - loss: 0.0149 - me - ETA: 1s - loss: 0.0148 - mean_ab
# Epoch 21/40
# 120587/120587 [==============================] - 12s 102us/step - loss: 0.0146 - mean_absolute_percentage_error: 98014.6250 - val_loss: 0.0637 - val_mean_absolute_percentage_error: 96281.4844oss: 0.0147 - mean_absolute_percentage_er - ETA: 8s - loss: 0.0146 - mean_absolu - ETA: 6s - loss: 0.0145 - mean_absolute_pe - ETA: 1s - loss: 0.0146 - mean_absolute_percentage_error:  - ETA: 1s - loss: 0.0146 -
# Epoch 22/40
# 120587/120587 [==============================] - 13s 105us/step - loss: 0.0145 - mean_absolute_percentage_error: 98496.0625 - val_loss: 0.0622 - val_mean_absolute_percentage_error: 92870.6484 mean_absolute_percentage_error: 60751. - ETA: 8s - loss: 0.014 - ETA: 4s - loss: 0.0145 - me - ETA: 3s - loss: 0.0145 - mean_absolute_ - ETA:
# Epoch 23/40
# 120587/120587 [==============================] - 12s 103us/step - loss: 0.0143 - mean_absolute_percentage_error: 97215.5547 - val_loss: 0.0599 - val_mean_absolute_percentage_error: 96905.1719 0.0140 - mean_absolute_perc - ETA: 3s - loss: 0.0142 - mean_abs - ETA: 2s - loss: 0.0143 - m - ETA: 0s - loss: 0.0144 - mean_absolute_pe
# Epoch 24/40
# 120587/120587 [==============================] - 12s 102us/step - loss: 0.0143 - mean_absolute_percentage_error: 98933.8750 - val_loss: 0.0621 - val_mean_absolute_percentage_error: 101737.1641lut
# Epoch 25/40
# 120587/120587 [==============================] - 13s 106us/step - loss: 0.0142 - mean_absolute_percentage_error: 97971.5312 - val_loss: 0.0606 - val_mean_absolute_percentage_error: 100145.4609s: 0.0142 - mean_absolute_percentage_error: 115031.656 -
# Epoch 26/40
# 120587/120587 [==============================] - 13s 107us/step - loss: 0.0140 - mean_absolute_percentage_error: 97672.2500 - val_loss: 0.0648 - val_mean_absolute_percentage_error: 95390.9609
# Epoch 27/40
# 120587/120587 [==============================] - 13s 107us/step - loss: 0.0140 - mean_absolute_percentage_error: 96956.4062 - val_loss: 0.0675 - val_mean_absolute_percentage_error: 94869.3750
# Epoch 28/40
# 120587/120587 [==============================] - 13s 105us/step - loss: 0.0141 - mean_absolute_percentage_error: 96933.4375 - val_loss: 0.0596 - val_mean_absolute_percentage_error: 99886.7578
# Epoch 29/40
# 120587/120587 [==============================] - 12s 104us/step - loss: 0.0138 - mean_absolute_percentage_error: 95757.3594 - val_loss: 0.0719 - val_mean_absolute_percentage_error: 92009.0391- loss: 0.01 - ETA: 0s - loss: 0.0137 - mean_absolute_percentage_error: 96379.90
# Epoch 30/40
# 120587/120587 [==============================] - 12s 102us/step - loss: 0.0138 - mean_absolute_percentage_error: 97795.9766 - val_loss: 0.0734 - val_mean_absolute_percentage_error: 97768.5000tage - ETA: 0s - loss: 0.0138 - mean_absolute_percentag
# Epoch 31/40
# 120587/120587 [==============================] - 12s 103us/step - loss: 0.0137 - mean_absolute_percentage_error: 98322.3203 - val_loss: 0.0687 - val_mean_absolute_percentage_error: 94820.2188: 0s - loss: 0.0137 - mean_absolute_percentage_error: 98961.
# Epoch 32/40
# 120587/120587 [==============================] - 13s 107us/step - loss: 0.0139 - mean_absolute_percentage_error: 96730.9297 - val_loss: 0.0720 - val_mean_absolute_percentage_error: 93837.1172
# Epoch 33/40
# 120587/120587 [==============================] - 13s 106us/step - loss: 0.0135 - mean_absolute_percentage_error: 96269.5000 - val_loss: 0.0690 - val_mean_absolute_percentage_error: 97758.6250
# Epoch 34/40
# 120587/120587 [==============================] - 13s 105us/step - loss: 0.0136 - mean_absolute_percentage_error: 97094.6094 - val_loss: 0.0736 - val_mean_absolute_percentage_error: 98112.3516e_percen - ETA: 2s - loss: 0.0136 - mean_absolute_percent - ETA: 1s - loss: 0.0136 - mean_absolute_percentage_error: 92888.46 - ETA: 1s - loss: 0.0136 - mean_absol
# Epoch 35/40
# 120587/120587 [==============================] - 12s 101us/step - loss: 0.0136 - mean_absolute_percentage_error: 96419.5703 - val_loss: 0.0705 - val_mean_absolute_percentage_error: 96301.3359
# Epoch 36/40
# 120587/120587 [==============================] - 12s 100us/step - loss: 0.0136 - mean_absolute_percentage_error: 96654.7500 - val_loss: 0.0627 - val_mean_absolute_percentage_error: 102988.0078- mean_absolute_perc - ETA: 3s - loss: - ETA: 1s - loss: 0.0135 - mean_absol
# Epoch 37/40
# 120587/120587 [==============================] - 12s 101us/step - loss: 0.0136 - mean_absolute_percentage_error: 96883.9922 - val_loss: 0.0697 - val_mean_absolute_percentage_error: 99249.32030s - loss: 0.0144 - mean_absolute_percentage_erro - ETA: - ETA: 0s - loss: 0.0136 - mean_absolute_percentage_error: 97513.87
# Epoch 38/40
# 120587/120587 [==============================] - 12s 102us/step - loss: 0.0135 - mean_absolute_percentage_error: 96552.7656 - val_loss: 0.0710 - val_mean_absolute_percentage_error: 99577.9922
# Epoch 39/40
# 120587/120587 [==============================] - 12s 102us/step - loss: 0.0132 - mean_absolute_percentage_error: 96003.8984 - val_loss: 0.0757 - val_mean_absolute_percentage_error: 97672.7188
# Epoch 40/40
# 120587/120587 [==============================] - 12s 103us/step - loss: 0.0134 - mean_absolute_percentage_error: 97093.1094 - val_loss: 0.0735 - val_mean_absolute_percentage_error: 97954.55470135 - mean_absolute_percentage_error - ETA: 4s - loss: 0.0 - ETA: 2s - loss: 0.0134 - mean_absolute_percentage_error - ETA: 2s -

# %%
import keras
model = keras.models.load_model(MODELS_DIR + "/" + "Second Model_000.h5")
predictions = model.predict(test_x)
print(test_x.shape)
# Out:
# (17213, 14, 5)

# %%
import matplotlib.pyplot as plt
plot_range = (3000, 5000, 1)
plt.rcParams["figure.figsize"] = (16,6)
plt.plot(np.arange(len(predictions))[plot_range[0]:plot_range[1]:plot_range[2]],
         predictions[plot_range[0]:plot_range[1]:plot_range[2]], label="Guess")
plt.plot(np.arange(len(predictions))[plot_range[0]:plot_range[1]:plot_range[2]],
         test_y[plot_range[0]:plot_range[1]:plot_range[2]], label="Test")
plt.legend()
plt.show()
