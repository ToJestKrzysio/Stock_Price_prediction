# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

selected_stock = yf.Ticker("TSLA")
# stock_price_history = selected_stock.history(period="max")
stock_price_history_dataframe = selected_stock.history(start="2020-01-01")

stock_price_history_price_keys = stock_price_history_dataframe.keys()[0:4]
stock_price_history = stock_price_history_dataframe[
    stock_price_history_price_keys].to_numpy()

plt.plot(stock_price_history_dataframe["Close"])
plt.xticks(rotation=90)
plt.show()
stock_price_history_dataframe.head()
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2019-12-31  81.000000  84.258003  80.416000  83.666000  51428500          0
# 2020-01-02  84.900002  86.139999  84.342003  86.052002  47660500          0
# 2020-01-03  88.099998  90.800003  87.384003  88.601997  88892500          0
# 2020-01-06  88.094002  90.311996  88.000000  90.307999  50665000          0
# 2020-01-07  92.279999  94.325996  90.671997  93.811996  89410500          0
#
#             Stock Splits
# Date
# 2019-12-31           0.0
# 2020-01-02           0.0
# 2020-01-03           0.0
# 2020-01-06           0.0
# 2020-01-07           0.0

# %% [markdown]
# # Data preparation
# Percentage growth of stock price was used to increase versitality, bacause stocks in long term don't have upper value bound.
# Additionaly it's extremely unlikely that widly know stock will rise more than a 100% in a day, so this method allowed to quickly obtain values within range (-1,1).

# %%
import sys
import numpy as np
import pandas as pd
np.set_printoptions(threshold=1000)

stock_price_history_percentage = np.zeros(stock_price_history.shape, dtype=float)
for index, row in enumerate(stock_price_history):
    if index != 0:
        stock_price_history_percentage[index,:] = \
            np.divide(row, stock_price_history[index-1,:]) - 1

sphp = pd.DataFrame(stock_price_history_percentage)
sphp = sphp.rename(columns={key: value for key, value in enumerate(stock_price_history_price_keys)})


close_price_percentage = stock_price_history_percentage[:,3]

time_bracket = 30
data_rows = (len(close_price_percentage)) - time_bracket - 1
input_data = np.zeros((data_rows,30), dtype=float)
output_data = close_price_percentage[time_bracket+1:]

for index in range(time_bracket, len(close_price_percentage)-1):
    input_data[index-time_bracket] = close_price_percentage[index-time_bracket:index]
    
input_data = input_data.reshape(input_data.shape[0], input_data.shape[1], 1)
output_data = output_data.reshape(output_data.shape[0], 1)
print(f" Input data shape: {input_data.shape}")
print(f"Output data shape: {output_data.shape}")

sphp.head()
# Out:
#  Input data shape: (305, 30, 1)
# Output data shape: (305, 1)
#        Open      High       Low     Close
# 0  0.000000  0.000000  0.000000  0.000000
# 1  0.048148  0.022336  0.048821  0.028518
# 2  0.037691  0.054098  0.036067  0.029633
# 3 -0.000068 -0.005375  0.007049  0.019255
# 4  0.047517  0.044446  0.030364  0.038801

# %%
import keras
from keras import models
from keras import layers
from keras import metrics

model = models.Sequential(name="First model")
model.add(layers.LSTM(units=25, activation="relu", return_sequences=True, input_shape=(input_data.shape[1], 1), name="LSTM_1"))
model.add(layers.LSTM(units=50, activation="relu", name="LSTM_2"))
model.add(layers.Dropout(0.1, name="Dropout_1"))
model.add(layers.Dense(units=100, activation="relu", name="Dense_1"))
model.add(layers.Dense(units=200, activation="relu", name="Dense_2"))
model.add(layers.Dropout(0.2, name="Dropout_2"))
model.add(layers.Dense(units=50, activation="relu", name="Dense_3"))
# model.add(layers.Dropout(0.15, name="Dropout_3"))
# model.add(layers.Dense(units=32, activation="relu", name="Dense_4"))
model.add(layers.Dense(1, activation="linear", name="classifier"))

model.compile(optimizer="Adam", loss="mean_squared_error", metrics=["mean_absolute_percentage_error"])
model.summary()
# Out:
# Model: "First model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# LSTM_1 (LSTM)                (None, 30, 25)            2700
# _________________________________________________________________
# LSTM_2 (LSTM)                (None, 50)                15200
# _________________________________________________________________
# Dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# Dense_1 (Dense)              (None, 100)               5100
# _________________________________________________________________
# Dense_2 (Dense)              (None, 200)               20200
# _________________________________________________________________
# Dropout_2 (Dropout)          (None, 200)               0
# _________________________________________________________________
# Dense_3 (Dense)              (None, 50)                10050
# ...

# %%
history = model.fit(input_data, output_data, batch_size=60, epochs=50)
# Out:
# Epoch 1/50
# 305/305 [==============================] - 1s 4ms/step - loss: 0.0028 - mean_absolute_percentage_error: 147.1526
# Epoch 2/50
# 305/305 [==============================] - 1s 2ms/step - loss: 0.0028 - mean_absolute_percentage_error: 114.1634
# Epoch 3/50
# 305/305 [==============================] - 1s 2ms/step - loss: 0.0028 - mean_absolute_percentage_error: 136.8887
# Epoch 4/50
# 305/305 [==============================] - 0s 2ms/step - loss: 0.0029 - mean_absolute_percentage_error: 235.7299
# Epoch 5/50
# 305/305 [==============================] - 1s 2ms/step - loss: 0.0028 - mean_absolute_percentage_error: 199.8542
# Epoch 6/50
# 305/305 [==============================] - 1s 2ms/step - loss: 0.0028 - mean_absolute_percentage_error: 149.9157
# Epoch 7/50
# 305/305 [==============================] - 1s 2ms/step - loss: 0.0028 - mean_absolute_percentage_error: 117.3316
# Epoch 8/50
# ...

# %%
import matplotlib.pyplot as plt



accuracy = history.history["mean_absolute_percentage_error"]
loss = history.history["loss"]
plt.plot(accuracy)
plt.show()
plt.plot(loss)
plt.show()
